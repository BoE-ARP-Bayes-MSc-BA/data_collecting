# %% [markdown]
# # packages

# %%
import numpy as np
import pandas as pd

import re
import string 

from collections import Counter

from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.metrics import confusion_matrix,classification_report, accuracy_score
from sklearn.linear_model import LogisticRegression

# %%
import nltk 
nltk.download('twitter_samples')
from nltk.corpus import twitter_samples
from nltk.corpus import stopwords          # module for stop words that come with NLTK
nltk.download('stopwords')
from nltk.stem import PorterStemmer        # module for stemming
from nltk.tokenize import TweetTokenizer   # module for tokenizing strings
# Out:
# [nltk_data] Downloading package twitter_samples to
# [nltk_data]     /Users/timliu/nltk_data...
# [nltk_data]   Package twitter_samples is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/timliu/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # prepare data

# %%
twitter_samples.fileids()
# Out:
# ['negative_tweets.json', 'positive_tweets.json', 'tweets.20150430-223406.json']

# %%
# documents
docs_negative = [(t, "neg") for t in twitter_samples.strings("negative_tweets.json")]
docs_positive = [(t, "pos") for t in twitter_samples.strings("positive_tweets.json")]
print(f'There are {len(docs_negative)} negative sentences.')
print(f'There are {len(docs_positive)} positive sentences.')
# Out:
# There are 5000 negative sentences.
# There are 5000 positive sentences.

# %%
# spliting dataset 
train_set = docs_negative[:3500] + docs_positive[:3500]
test_set = docs_negative[3500:4250] + docs_positive[3500:4250]
valid_set = docs_negative[4250:] + docs_positive[4250:]

# %%
train_set
# Out:
# [('hopeless for tmr :(', 'neg'),
#  ("Everything in the kids section of IKEA is so cute. Shame I'm nearly 19 in 2 months :(",
#   'neg'),
#  ('@Hegelbon That heart sliding into the waste basket. :(', 'neg'),
#  ('“@ketchBurning: I hate Japanese call him "bani" :( :(”\n\nMe too', 'neg'),
#  ('Dang starting next week I have "work" :(', 'neg'),
#  ("oh god, my babies' faces :( https://t.co/9fcwGvaki0", 'neg'),
#  ('@RileyMcDonough make me smile :((', 'neg'),
#  ('@f0ggstar @stuartthull work neighbour on motors. Asked why and he said hates the updates on search :( http://t.co/XvmTUikWln',
#   'neg'),
#  ('why?:("@tahuodyy: sialan:( https://t.co/Hv1i0xcrL2"', 'neg'),
#  ('Athabasca glacier was there in #1948 :-( #athabasca #glacier #jasper #jaspernationalpark #alberta #explorealberta #… http://t.co/dZZdqmf7Cz',
#   'neg'),
#  ("I have a really good m&amp;g idea but I'm never going to meet them :(((",
#   'neg'),
#  ('@Rampageinthebox mare ivan :(', 'neg'),
#  ('@SophiaMascardo happy trip, keep safe. see you soon :* :(', 'neg'),
#  ("I'm so tired hahahah :(", 'neg'),
#  ('@GrumpyCockney With knee replacements they get you up &amp; about the same day. :-(   Ouch.',
#   'neg'),
#  ('relate to the "sweet n\' sour" kind of "bi-polar" people in your life... cuz my life... is FULL of them... :(',
#   'neg'),
#  ('@aysegul_k pleasse :(', 'neg'),
#  ('@SexyKalamo im not sure tho :(', 'neg'),
#  ("I feel stupid\nI just can't seem to grasp the basics of digital painting and nothing I've been researching is helping any :(",
#   'neg'),
#  ('Good Lord. :( https://t.co/nC9LkYUUvO', 'neg'),
#  ('I feel lonely someone talk to me guys and girls :(\n\n@TheOnlyRazzYT @imarieuda @EiroZPegasus @AMYSQUEE @UdotV',
#   'neg'),
#  ('No Assignment, but we have Project. :( really? 😩', 'neg'),
#  ('just want to play video games/watch movies with someone :(', 'neg'),
#  ('choreographing is hard : (', 'neg'),
#  ("@xo_raaaaayyy_xo what the email link? Still says that it's no longer available :( http://t.co/iuiaIOynnx",
#   'neg'),
#  ('cries bc i miss mingming so much :-(', 'neg'),
#  ('Sorry :( https://t.co/Q5TAYjrQ8K', 'neg'),
#  ('@Giannivnni mom so far away :(', 'neg'),
#  ("We're truly sorry @chrisbrown :( have a safe flight.", 'neg'),
#  ('and my friends :(', 'neg'),
#  ('@bbygjrlmgc oh :( i hate when that happens i get so sad over it too',
#   'neg'),
#  ('Oh. Dog has pee’d in my @Kneewax bag.  :-(   So I can’t take it to #NewWine15',
#   'neg'),
#  ('@YM_Dish98 doushite :( ?', 'neg'),
#  ('@Charliescoco @reeceftcharliie @SimonCowell too late :(', 'neg'),
#  ('It sucks so much been sick i was plan to start work on my first gundam to night but nope. :(',
#   'neg'),
#  ('MY $$$$2 DOLLAR :( 😭😭😭😭😭😭 http://t.co/oI0pYGUsDi', 'neg'),
#  ("@martylog Listening back to old @DaveGorman shows (I know, I'm weird). Just got to u leaving: might give up. It was pale imitation after :-(",
#   'neg'),
#  ("i went in the sea and now have a massive fucking rash all over my body and it's the most painful thing ever i want to go home :((",
#   'neg'),
#  ('@dethronedlwt hi. Why are you absent? :(', 'neg'),
#  ("My Gran tho !!! She knew but didn't care to tell me :((", 'neg'),
#  ("@rowysoIjp SAME IT'S SO CUTE I LOVE IT SO MUCH I WISH THERE WOULD BE A SEQUEL :(",
#   'neg'),
#  ('@imallyssagail busy sa school :( next time love yah! xx', 'neg'),
#  ('Ouucchhh one of my wisdom teeth are coming through :(', 'neg'),
#  ('@StevenLDN frightening case. It really gets to you :(', 'neg'),
#  ('pret :(( wkwkw"@WLK_Jhope: Verfied @WLK_Hyemi91 be active, don\'t forget to follow all member. Thanks for join. Goodbye"',
#   'neg'),
#  ('You´ve got me in chains for your love :´( — a sentir-se incompleta', 'neg'),
#  ("it's okay.. but.. :((", 'neg'),
#  ("@njhftbiebs why didn't you go on Wednesday :(", 'neg'),
#  ('@radicalj  Marvellous - not. How very thwarting :-(', 'neg'),
#  ("@ceeels95 Awh what's the chances 😩 when u off to Zante? We need to do something :-( x",
#   'neg'),
#  ("@s0ulfl0wr When's your birthday ? :(", 'neg'),
#  ('@brittleyouth @Tom_J_Allen @AndrewFairbairn @batemanesque @Hegelbon @jameswheeler that was the worst part and I still feel bad about it :(',
#   'neg'),
#  ('audraesar: All these sushi pics on my tl are driving me craaaazzyy :(',
#   'neg'),
#  ('Really want this :( http://t.co/36tSy81iMi', 'neg'),
#  ('Popped like a helium balloon..  :-(', 'neg'),
#  ("#ClimateChange #CC California's powerful and influential air pollution watchdog.: Califor... http://t.co/OVU4p2qWfH #UniteBlue #Tcot :-(",
#   'neg'),
#  ('@itsNotMirna I was so sad because Elhaida was robbed by the juries :( she came 10th in the televoting',
#   'neg'),
#  ('#ClimateChange #CC Idaho will not restrict fishing despite regional drought-linked die-of... http://t.co/jJboDo6LYZ #UniteBlue #Tcot :-(',
#   'neg'),
#  ('#ClimateChange #CC Abrupt climate change may have doomed mammoths and other megafauna, sc... http://t.co/taVMCz37E7 #UniteBlue #Tcot :-(',
#   'neg'),
#  ("#ClimateChange #CC Australia's 'dirtiest' power station considers 'clean energy' biomass ... http://t.co/YeQABq6tsL #UniteBlue #Tcot :-(",
#   'neg'),
#  ("#ClimateChange #CC It ain't easy being green if you're a golf course in California.: Ulti... http://t.co/La82RXzTs2 #UniteBlue #Tcot :-(",
#   'neg'),
#  ('@Mess0019 Well I am sure your work day is over before mine :(', 'neg'),
#  ('@keikopotato IM GONNA MISS U SEXY PREXY :(((((((((', 'neg'),
#  ('i miss my kindergarten kids :(', 'neg'),
#  ('HUNGRY :-(', 'neg'),
#  ('cant find the only book that keeps me sane :((', 'neg'),
#  ("Literally there are three lounge events why :-( So much turn up I'm sad",
#   'neg'),
#  ('@carliot23 Miss you Boss :(', 'neg'),
#  ('I love hozier :-(', 'neg'),
#  ("@IzzyTailford that's true, I just want it soooooooner :(", 'neg'),
#  ('Ahh Fam @MeekMill :( #RespectLost http://t.co/NT25MYnGYd', 'neg'),
#  ("@shokako1104 I'm sorry :( ! What is hypercholesteloremia ? Are you ok ?",
#   'neg'),
#  ('Baby still looks tired :(', 'neg'),
#  ('Can someone gift me calibraska :(', 'neg'),
#  ("@Rico_Shabbir the massive shame about it is we would actually be genuine contenders but it won't happen :(",
#   'neg'),
#  ('My head always hurts if I stay up late lmao :(', 'neg'),
#  ('@ErnestLozoya how are u older than me :(', 'neg'),
#  ('Backed out :(', 'neg'),
#  ('u sound upset :( https://t.co/JZBFBKld8Q', 'neg'),
#  ('So much misses :-( https://t.co/pn2HvGdnFT', 'neg'),
#  ('I MISS INFINITE :-(', 'neg'),
#  ("@DiscoQing AoS doesn't do it for me but I don't want to stick with 8th either. :(",
#   'neg'),
#  ('@madrigalandreaa its too much  serious yun eh :(', 'neg'),
#  ('My room is way too hot :-(', 'neg'),
#  ('I still havent found my Handsome Jack drawing :((((', 'neg'),
#  ('@twcxmina shit :(', 'neg'),
#  ('But cut encore :(((( #bad4thwin', 'neg'),
#  ('I wish I had my own Baymax :(', 'neg'),
#  ('Sick :(', 'neg'),
#  ('@LittleMix French mixers miss you so much :( 💜', 'neg'),
#  ("Wft.. can't watch the awesome replay!! :-( https://t.co/ChzrqtelPh", 'neg'),
#  ('@Viiiiiiiiev what happened?? :(((', 'neg'),
#  ('Party promotions are over :(', 'neg'),
#  ('Music bank encore always so short :(', 'neg'),
#  ('BABY BOY :((((', 'neg'),
#  ("@flipkartsupport my order has been received at the hub nearest but doesn't look like it will be delivered today :( (1/2)",
#   'neg'),
#  ('Why is my mum playing music out loud :(', 'neg'),
#  ('The finale of Parasyte fucked my feelings alllllll the way up :(', 'neg'),
#  ('i wish :( #ZaynIsComingBackOnJuly26', 'neg'),
#  ('Good bye Party era :(', 'neg'),
#  ('@amedefu Me  too。。。_:(´ω`」 ∠):_', 'neg'),
#  ('@Concept_Nathan nathann💕 I never got a chance to take a pic with you :( got a hug tho! Pic next time I see you?😊',
#   'neg'),
#  ('some girl came up to me and was like "you are so beautiful :-(" I want to dieididieieiei she\'s so cute',
#   'neg'),
#  ('Party goodbye stage :( but this means Hello to Lion Heart and You Think',
#   'neg'),
#  ("@MsDanneh @Obey_Ervin15 Tell her to screw herself. I'm gonna have a netflix and chill on my own. Y u do dis ervin :(",
#   'neg'),
#  ('@subharrie ohh no :(( and yeah i hope she comes back soon too', 'neg'),
#  ("@MadniTahir I am. I've accepted the offer..but im desperate to take the year out.   :(",
#   'neg'),
#  ('Come back :(', 'neg'),
#  ('Snapchat me - AmargoLonnard #snapchat #snapchat #kikhorny #snapme #tagsforlikes #batalladelosgallos #webcamsex :( http://t.co/3S9LHaFrsU',
#   'neg'),
#  ('UGH I CANT STREAM TMR I HAVE DUTY :(', 'neg'),
#  ("@madrigalandreaa u've gone too far :(", 'neg'),
#  ('@uhhAileeny What about her alien thing :(((', 'neg'),
#  ("@Ni_All_Is_Bae aww I don't really wanna get my hopes up but I wish that he would :((",
#   'neg'),
#  ('@malikm0ney sorka no :((', 'neg'),
#  ('@fxnno_ i knew u would be sad :( were having a funeral i was gonna text u but i have no phone',
#   'neg'),
#  ('Sunny :( i feel so bad.... http://t.co/17tca0uhKp', 'neg'),
#  ('So nonexistent wowza :(', 'neg'),
#  ("@izgzb @aishahyussofff back off fah she's mine :-(", 'neg'),
#  ('@DIMPLEDJAI taylor why did you crop yourself out :(((((((((((((((', 'neg'),
#  ('@nickjdrake Boo on both counts :-(', 'neg'),
#  ('new guitar :(', 'neg'),
#  ('@PinkCloud_RP so when will i get my jonghyun hyung? :( please predict it :(',
#   'neg'),
#  ('I hope SJ will be nominated soon but no SJ vs INFINITE pls :(((((', 'neg'),
#  ('Yeah dudes, keep calm and brace yourselves :-( https://t.co/ZnOjT3v9Gq',
#   'neg'),
#  ('@Mr_FRML sir plus 4 please :((', 'neg'),
#  ('THEY LOOKED SO SHOCK OMGGGG :((( YALL DESERVE IT :((((', 'neg'),
#  ('Whenever I would spend the night we would smoke and watch a movie but he would always end up falling asleep on me :(',
#   'neg'),
#  ('We were 1 point close to grand finals! :( whyyy', 'neg'),
#  ("@muhammadskates :( that's a long time", 'neg'),
#  ('@evanquick Oh, that must be so annoying Evan :( Do the texts give the option to opt out?',
#   'neg'),
#  ("Who's doing giveaways for muster goods? :( or any merchs", 'neg'),
#  ('@wendyykid ah too bad :(', 'neg'),
#  ("People are looking at me funny because I'm drinking savanna with a straw :(",
#   'neg'),
#  ('Good bye stage :((((', 'neg'),
#  ('@ameliahartin AND WHY DID YOU IGNORE ME YESTER AFTERNOON :(', 'neg'),
#  ("I can't sleep :( someone talk to me", 'neg'),
#  ('yeah :(', 'neg'),
#  ('@_Birexus yes sadly :(.', 'neg'),
#  ('@ClaireClaire05 Very :(', 'neg'),
#  ('@The_Strypes whens the album coming? :(', 'neg'),
#  ('The last of my chocolate has been consumed. :(', 'neg'),
#  ('ugh i have werk in the morning too :-(', 'neg'),
#  ('@Deedee_50Fly foreals :( a wesen uwesiti mj 😂😩', 'neg'),
#  ("@crazynovely I will if I catch him online long enough - haha!  He's being very annoying!!  :(",
#   'neg'),
#  ('Bosen :(', 'neg'),
#  ('Dying for some egg benny :(', 'neg'),
#  ('@Michael5SOS Sometimes I hate you :((', 'neg'),
#  ('@Mark23Baracael baby followback huhu :(', 'neg'),
#  ('@fkluca but no ones as cute as u so :(', 'neg'),
#  ("@Tinkkza You're gonna watch this shit and understand how badly you scared me! &gt;:( https://t.co/YcGudITQgx",
#   'neg'),
#  ('I miss Al, Katie, Zaz and Amy a lot :((', 'neg'),
#  ('I liked a @YouTube video http://t.co/2JcBiswDW9 More subs plz :(', 'neg'),
#  ("@LittleMix @SonyMusicNL Can u make a diary while you're all there please :((",
#   'neg'),
#  ('@neikmat Sorry :(', 'neg'),
#  ("@twyodor @gkjohn :-( I don't read most of these rehash websites that have mushroomed. A good piece may be by exception &amp; reaches one anyway.",
#   'neg'),
#  ('@daddyksoo and yes its been a while vicky omg :-(((((', 'neg'),
#  ('@megsyfoxie WTF LIKE YOUR LIPS STILL A VIRGIN OMG MOM GET A LIFE YOURE 45 \n\nHahah : (',
#   'neg'),
#  ('@pastelwolfxx @CHA_NNNNN niNASTY tsktsk oppa wont like u call his dick kawaii he is manly &gt;:( http://t.co/83cUgt7qQ3',
#   'neg'),
#  ('So Lonely :( http://t.co/VM4N0n8Bkw', 'neg'),
#  ("can't go back to sleep :((", 'neg'),
#  ('i wanna go on xbox for netflix but am already too comfy in bed :(', 'neg'),
#  ('@baileymac02 miss youu :(', 'neg'),
#  ('sigh i feel bad for our girls :(', 'neg'),
#  ('@oH_So_EhmTee lol! I love sweet potato fries :(', 'neg'),
#  ("@_Birexus guess y'all ugly asf HUH :(", 'neg'),
#  ('@Dsitando eish ive been quit i know...i lost my twitter mojo shame...n i dont know how to get it back :( mara im sure you can help me neh',
#   'neg'),
#  ("aww i've got a fever :( but #bad4thwin &lt;3", 'neg'),
#  ('Poor bb :(', 'neg'),
#  ("@UrsulaWJ @OwenWinterMYP I'm not able to go! :( It's the Association of Green Councillors conference this weekend...",
#   'neg'),
#  ("My skype account is out of order. I think it's been hacked. So if you were in my contacts I'm sorry :( I'm creating a new one soon.",
#   'neg'),
#  ('@selenagomez i miss your tweet spree oh :(', 'neg'),
#  ('Yes na! As sholong reject my proposal :( "@elzzika: Gee U don fly go gidi? "@Gatlinho: The way i\'m being pampered in this lagos ehn....""',
#   'neg'),
#  ('@isxbe i guess im arresting my girlfriend :((', 'neg'),
#  ('@prophdog_ @attepate hes such a nice person idk why anybody would say that to him :(',
#   'neg'),
#  ("You know when a song just disappears from your phone and iTunes? I've lost Dazed and Confused :(",
#   'neg'),
#  ('FEVER. :-(', 'neg'),
#  ('"Do you think they survived???"\n"Well, they did find all the missing bodies in fragments, so no. But it would\'ve been nice if they did." :(',
#   'neg'),
#  ('@DareToAttar im being forced to go :-(', 'neg'),
#  ('Horrible weather to be going to work in :(', 'neg'),
#  ('@okayshesaid wish that both of us could change this :(', 'neg'),
#  ('walao kbs never show encore :(', 'neg'),
#  ('Sending. Finally!!!!!!!!!!!!!! :(', 'neg'),
#  ('Being ill is the worst :(((', 'neg'),
#  ('its not the same. :(((((', 'neg'),
#  ('Hope #DJDerek is found safe &amp; well had many fun times at his gigs, absolute legend :(',
#   'neg'),
#  ("@qtbatooty_ yeah and it's like why do you need to wait till saturday to give us homework pa :((((((( WHAT IF U MADE PLANS 4 DA WEEKEND????",
#   'neg'),
#  ('Greek Tragedy is such a cute song :((((', 'neg'),
#  ('@bammyxoxo @stffnkthx @breeyanuh16 same :(', 'neg'),
#  ('Raining on me today :( \n\nGym it is then 💪🏻🐒', 'neg'),
#  ('@cutelilawley whats wrong? :(', 'neg'),
#  ("Oh god!!! I'm strucked by the pain... Cant take it anymore!!! :(", 'neg'),
#  ('@LittleMix come to Belgium :(', 'neg'),
#  ('Fabian Delph has fallen :(\n@BLUEARMY_IND @MCFC', 'neg'),
#  ('@rosicky1987 WHERE U BEEN HIDING BABY :((', 'neg'),
#  ("I'm draking silently so they can't hear it :(", 'neg'),
#  ('Rest in peace mo :(', 'neg'),
#  ('@MHSScho not much chance of game tonight :( #t20blast', 'neg'),
#  ("@OL_EYY ahhh u see? U wouldn't wake up :(", 'neg'),
#  ('Mumma! Im on 7% :( @LMCDark_Angel', 'neg'),
#  ('@sarahhardman8 I hope so :(', 'neg'),
#  ("I'm gonna be dead tomorrow :(:", 'neg'),
#  ("@_Dedox :( I'll do high you do low", 'neg'),
#  ('@hanbined sad pray for me :(((', 'neg'),
#  ('@BritishSignBSL how very appropriate! :(', 'neg'),
#  ('@RedsOrDead poor him. . . :(', 'neg'),
#  ("I'm still awake :(", 'neg'),
#  ('woke upp now i cant sleep :(', 'neg'),
#  ('No one is up to help me :(', 'neg'),
#  ("@curlsharryxoxo i don't know :(( just be happy for him :(", 'neg'),
#  ('@blvsamx hi, can you do me some dms with luke please ?:(', 'neg'),
#  ('@KanchuDarling @VidyutJammwal hey babe i just came across this pic..what is this about? I cant read hindi :(',
#   'neg'),
#  ('their reactions :(((((', 'neg'),
#  ("@junghoseoks 5s :( i think it's bc im running out of space tbh", 'neg'),
#  ('@rustyrockets I wish I could come and see you but on Disability pension with PTSD makes it impossible both physically and financially :(',
#   'neg'),
#  ('Why does it have to rain :(', 'neg'),
#  ('@Foooer_Hungary @FoooerSG nooo why they broke up!!! They were soo amazing togheter!! :(',
#   'neg'),
#  ('@MystikGunn suck for me which mean I have to watch you play it around 1 p.m. my time :(',
#   'neg'),
#  ("Don't be like that :(  https://t.co/gaWf0bsr6A", 'neg'),
#  ('@derekklahn You cant hold another week? September 21st. :-((', 'neg'),
#  ('why they cut the encore i wanna see snsd infinite interaction :(', 'neg'),
#  ('i miss watching anna akana videos :(', 'neg'),
#  ("@tokyato askip t'existes pas :(", 'neg'),
#  ('@9_Moore Sadly not :( - the channel owner decides which regions it broadcasts to. Thanks, Kei. Please rate our se... https://t.co/EzfeHMTT5S',
#   'neg'),
#  ('i dont think @camerondallas  or @JackAndJackReal  will ever notice me :( I STILL EXIST',
#   'neg'),
#  ('The traffic is terrible :(', 'neg'),
#  ("@joaannelopez I've been eyeing on a small kate spade bag too! Pero walang maganda :(",
#   'neg'),
#  ("@mermaid_bl00d haha aw, I miss you too! Haven't seen you for agessss :(((",
#   'neg'),
#  ('@energybiebers Sigh... :(', 'neg'),
#  ('Add me on Snapchat - CorineHurleigh #snapchat #snapchatme #instagram #addmeonsnapchat #sfs #quote #kiksexting :( http://t.co/8bk7ptaqaR',
#   'neg'),
#  ('I have no bum in Zara trousers :(', 'neg'),
#  ('All these sushi pics on my tl are driving me craaaazzyy :(', 'neg'),
#  ('My after effects not spanish :(', 'neg'),
#  ("Aww the poor thing :( Hope it'okay and in good health. luckely it has been freed from those Rocks #orcalove https://t.co/tOSZMOafv6",
#   'neg'),
#  ('@Techverse_in first i tried this http://t.co/XTSzpi9fQW but no result :(',
#   'neg'),
#  ('I want my braces back! :(', 'neg'),
#  ("I need a big cuddle from Lew and kisses on my face :(((( I don't want to go through this again",
#   'neg'),
#  ('@xcrazy90skidx @kowtsnatinito @_patnicolexx ems haha :(', 'neg'),
#  ('Craving for Banana Crumble McFlurry and Fries :(', 'neg'),
#  ("We're not going on the cable cars now because my brother got scared and doesn't want to :(((",
#   'neg'),
#  ("i miss hello venus's old concepts tbh i rly like do you want some tea :(",
#   'neg'),
#  ('tagal :(', 'neg'),
#  ("We've lost in album and broadcast points :( http://t.co/QDSVS5Q9SR", 'neg'),
#  ("i have this awful appointment tomorrow and i'd like to feel OK going in to it, since I won't be after it &gt;:(",
#   'neg'),
#  ('This sucks I want to go home :(', 'neg'),
#  ("There's no milk left for my cereal :(", 'neg'),
#  ('@shahrukh9899 @IamMansoorKhan Huh :( yes', 'neg'),
#  ('we lost at the album and broadcast :((((', 'neg'),
#  ('So sad :( http://t.co/fVV9Y3WX2o via @EvokeToday', 'neg'),
#  ('Everything and all :(', 'neg'),
#  ('@RealLiamPaynePH follow me :((', 'neg'),
#  ('@sainsburys yeah, I tried to film the date at the start. At the time of filming it had 4 days left.  :(',
#   'neg'),
#  ('@namwngr no, because you will get more than one and i think its not the same from the previous one :(',
#   'neg'),
#  ("I can't smile :(", 'neg'),
#  ("I'm following 73 users who aren't following me back.  :(", 'neg'),
#  ('when will got7 : (', 'neg'),
#  ('@craigyboi seems to be everywhere today :(', 'neg'),
#  ('@OliviaKaparang @BTS_twt for the fansign and take photo is more expensive :(',
#   'neg'),
#  ("Zzzzzz.....please don't let the sun come up yet.... :(", 'neg'),
#  ("When your bff's extremely stressed and you can't do anything but pray... \n\n:(",
#   'neg'),
#  ('ahh no win for the goodbye stage :(', 'neg'),
#  ("@st3cav @MCFC @sterling31 @YayaToure True, deosn't help that Liverpool were here last week, most have never been to Pool though :(",
#   'neg'),
#  ('@ArunbuddyAP yes bro..lost many too :(', 'neg'),
#  ('@JindalDaily praying for you all. So sorry this happened : (', 'neg'),
#  ('@jackshilling Great news, thanks for letting us know :( We hope you have a good weekend!',
#   'neg'),
#  ("@peachyIauren it's so fucked :(", 'neg'),
#  ('@LocoTaii - My self esteem was on the lowest :(', 'neg'),
#  ("@RyanBitchTits they feel and look better where people can't see tbh\nThey look so tacky :((",
#   'neg'),
#  ('@fabssulli taken say :(', 'neg'),
#  ('@ASVPxGABE man all I got is lucky charms :((((', 'neg'),
#  ('#Haaretz #Israel :-( Syria continues to develop chemical weapons, officials tell WSJ: WSJ rep... http://t.co/3c5PRCHKqw #UniteBlue #Tcot',
#   'neg'),
#  ('i want all these bts merchs :(((', 'neg'),
#  ('Only one more day :(', 'neg'),
#  ('Should have taken a pic before mrs wong confiscated my art work :(', 'neg'),
#  ('#Bad4thWin you guys omg :((((((', 'neg'),
#  ("@mustntgrumble I hadn't thought of an icepack. Big doses of pain killers on board. But it is feeling very very painful already :( *whimpers*",
#   'neg'),
#  ("it's okay :(", 'neg'),
#  ('@ABeezyGMT says the Man U fan :(', 'neg'),
#  ('@BIBBYUPDATES :(( I wish I could be there to say a final goodbye to them',
#   'neg'),
#  ('@_awkwardraven Will do Senpai &gt;:( -looks up on all of buttsex-', 'neg'),
#  (".@sabal_abla @tanha_messiah But I was joking on the headline. So aren't we friends? :( Pls dn't brk my heart. :'(",
#   'neg'),
#  ('When someone hits a head voice and I\'m like "I would sound amazing if I could do that too." But no... I can only do falsettos :(',
#   'neg'),
#  ('@Patrickcf26 NOTICE ME :(((', 'neg'),
#  ('@versacelopez I hate our time zone :(', 'neg'),
#  ('MY snapchat - LeanneRiner19 #snapchat #hornykik #loveofmylife #dmme #pussy #newmusic #sexo :( http://t.co/TyhwG534Ng',
#   'neg'),
#  ('@DominionSyfy when will S2 be aired in Spain?? The delay is killing us... :(',
#   'neg'),
#  ('@TheOnion @ChoKyungHoon82 not a single untruth here :(', 'neg'),
#  ("My last cross country in IJ was amazing!!!!!!!💥✨💫 Can't bear to leave :-( https://t.co/VkVOxIaEQn",
#   'neg'),
#  ("@_lizzy_kay I can't drive so :(", 'neg'),
#  ('when I have my own little apartment can like someone come live with me :-(',
#   'neg'),
#  ('soshi didnt win :(( buttt congrats infinite!! #bad4thwin', 'neg'),
#  ("@rickygervais I'm working Saturday and Sunday so Friday is a bad day for me :(:(",
#   'neg'),
#  ('going home soon :(', 'neg'),
#  ("I shoulda moved away w my boys when I had the chance cause they're the only people I want at times like this :(",
#   'neg'),
#  ('Heyyyyy i wanted to see yeols solo danceeeeee :((((((((((((((', 'neg'),
#  ("Inter offer Nemanja Vidic to Roma...but they don't want him either :( http://t.co/Ksdgy0lTpF http://t.co/FplKjpXNQN",
#   'neg'),
#  ("My mom's a linguist. My dad's a computer scientist. And I am the dumbest one in the family :-(",
#   'neg'),
#  ('@GizmodoUK broken for me :( I really wanted my morning ice cream in the pouring rain... http://t.co/y9waxvQKpg',
#   'neg'),
#  ("@hankgreen would you ever consider creating crash course videos about computer science? There aren't many resources at my school :(",
#   'neg'),
#  ('@Uber all ice cream vehicles are busy :(', 'neg'),
#  ('ate ayex what do you eat? youre sexy :((( — I swear I eat a lot. No chill lamon haha http://t.co/CfOxw5wljZ',
#   'neg'),
#  ('This weather has me scrolling through my contacts of people I\'ve curved on some "hey you 😉" sigh* :(',
#   'neg'),
#  ("so i'll be getting my cement cast tomorrow :(", 'neg'),
#  ('Shit 10.3k???? :(((((', 'neg'),
#  ('*sign out* :(((((( https://t.co/y45q9GAJ5j', 'neg'),
#  ('@zaynmalik zayn :((', 'neg'),
#  ("(bot) If you follow me, plz send to me mention. Because I can't notice :(",
#   'neg'),
#  ('these JMU camps are such a tease bc I just wanna be here now :(', 'neg'),
#  ("@mizznhee that's one of the sweetest things I've ever said, awuna mbulelo :(",
#   'neg'),
#  ("This fucking bad link isn't working and I can't watch the match! :(",
#   'neg'),
#  ("Oh no Mr I Pigs not turning on :( although there's a weird crackling noise when I plug him in coming from the plug ,I'm thinking fuse?",
#   'neg'),
#  ('@TitusOReily dammit I tipped Carlton :( #AFLBluesHawks', 'neg'),
#  ('@baileymac02 miss you :(', 'neg'),
#  ('@jiministic go to bed :(', 'neg'),
#  ("Am want to go Alex's house :(", 'neg'),
#  ('@MotorsportCntrl @GP2_Official so true! This was part of a motorsport series (all on one disc) :(',
#   'neg'),
#  ("All I want right now is the A, followed by the D and a cheeky J after that\n\nInstead I've got some SEO and some NLs to be getting on with :(",
#   'neg'),
#  ('@BOYBANDSFTCARA sure!!! Sorry :( x', 'neg'),
#  ("@talkingsimpsons hey bud! Christy is really sick so I can't leave these 2 at home :( xo thanks man",
#   'neg'),
#  ('My niece is having a better summer then me :(', 'neg'),
#  ('I just wanted a bloody sandwhich :(', 'neg'),
#  ('@Whorgeee :( it is', 'neg'),
#  ('Buset :( https://t.co/hQ4y4FKniZ', 'neg'),
#  ('#Discrimination :-( Five things we learned about pregnancy discrimination today | Left Foot F... http://t.co/Ey9MmaSmsd #UniteBlue #Tcot',
#   'neg'),
#  ('#Discrimination :-( Maternity discrimination: When I needed my boss, he kicked me in teeth - ... http://t.co/2WT4YyMNWz #UniteBlue #Tcot',
#   'neg'),
#  ('#DomesticViolence :( Proposed New Law Will Help Domestic Violence Victims - 98FM: Victims ... http://t.co/eoISmrzLpo #UniteBlue #VAW :-(',
#   'neg'),
#  ('@nnoonlight i missed you :( it was okay. lol. I did nothing. 😂', 'neg'),
#  ('@hamzaabasiali exactly but unfortunately :(', 'neg'),
#  ('Such a stressful and upsetting day yesterday, the UK government sucks :(',
#   'neg'),
#  ("Ugh, well I could still say that I'm lucky because I am Sapiosexual. :((((",
#   'neg'),
#  ('Aww too bad :(', 'neg'),
#  ('Ive been trying to play the damn beta for like 12 hours now :(', 'neg'),
#  ("I don't want to be in a world where Hulk Hogan has been scrubbed from WWE history :-(",
#   'neg'),
#  ('im so tired! :(', 'neg'),
#  ("This weather isn't making me want to go to the gym at all..... :-(", 'neg'),
#  ("@katjturgoose @artsjobs Link doesn't work! :(", 'neg'),
#  ('Irene seemed so sad after making that mistake :(', 'neg'),
#  ("@ItssssKelseyyyy Naa unfortunately, I didn't have my phone on me :(",
#   'neg'),
#  ('@bmthofficial ITS SOLD OUT :((((((((((((((((((((((((((((((((((((((((((((((((((((((((((',
#   'neg'),
#  ('i hate u &gt;.&lt; &gt;:( #H_My_King', 'neg'),
#  ('we lose again :(', 'neg'),
#  ("Valentine et al found r'ships btwn homo/biphobic comments &amp; certain disciplines - incl. European langs, lit, education :( #fresherstofinals",
#   'neg'),
#  ("when will you notice me :( i'm so hopeless 💔 @SeaveyDaniel", 'neg'),
#  ('my dreams are gettin too realistic for my liking thx !!! cant tell whats real n what isnt :((((',
#   'neg'),
#  ("@SidebySide either or but would prefer Benzema! We won't get any though :(",
#   'neg'),
#  ('@dontvexmysoul hahahahahaah i donno korean language :( only few russian ) waaaaa',
#   'neg'),
#  ('@Grofers what about me? :( #EidWithGrofers', 'neg'),
#  ("Someone talk to me I'm boreddd :(", 'neg'),
#  ("don't you just hate it when you get called a mug \npisses me off &gt;:(",
#   'neg'),
#  ('"@MgaPinoyPatama: I miss you, but I know you don’t care." :((', 'neg'),
#  ("@alexmcgraaa no I can't do it, don't have the option on my phone :(",
#   'neg'),
#  ('@CelestialSinn I love Tiddler, but that was really silly :( but at least we’ll be getting real new cards in like 1 hour..',
#   'neg'),
#  (':( well this sucks', 'neg'),
#  ('Infinite win :(', 'neg'),
#  ("@SBS_MTV Are you sure that Chorong is the leader? #에이핑크 #더쇼 I can't be sure anymore :(",
#   'neg'),
#  ('@ClashWithCam when will the clan slots be open :((', 'neg'),
#  ('Pffff doing a private @Bugcrowd #bugbounty and only finding self-XSS and host header poisoning :( Need some code execution #ktksbye',
#   'neg'),
#  ("When your connect leaves a company and they don't alert you :(", 'neg'),
#  ('.@uberuk you cancelled my ice cream uber order. Everyone else in the office got it but me. :(',
#   'neg'),
#  ('@Nebula2592 ahahah i consider it petite, i have a love hate relationship with my height :(',
#   'neg'),
#  ('@therp_stefan @Therp_BV will cost you 600 k£ to get security alerts on odoo 8 if you are an Odoo partner. Far from community spirit. :-(',
#   'neg'),
#  ('jgh :( im so effin tired', 'neg'),
#  ('facebook, y u no work ? y u do this facebook ? :(', 'neg'),
#  ('No ones up :((', 'neg'),
#  ('@TheNameIsJase No unfortunately :( Sorry!', 'neg'),
#  ("Anyone else's show box not working?!?!?:(:(:(:(:(", 'neg'),
#  ("AP won't be the same anymore :-(", 'neg'),
#  ("@llymlrs story of my life...!! Love London and can't imagine living elsewhere but it's gonna have to happen someday :( I have NO space!",
#   'neg'),
#  ('@benrwms Oh no Ben :-( That is terrible, please provide us with the name of the branch you visited. We would like to address your concern.',
#   'neg'),
#  ('Poor guy :( http://t.co/aSq9NN4AXR', 'neg'),
#  ("@elninakauser I feel your pain, It's like the Welsh Pod all over again  :(",
#   'neg'),
#  ("@buterasfredo i can't wait for the movie to come out :(", 'neg'),
#  ("@littlejules14 Hi Julie, I'm sorry you feel this way :( Whats happened? ^Laura",
#   'neg'),
#  ('@maknaekookie i cant :-( im still inside the train station waiting for the person ;_; home is another hour away D;',
#   'neg'),
#  ('@vegemitegrier not anymore :(', 'neg'),
#  ('@wendykims @Joix05 @GiladMillo some people need not to talk-kama hawako around :( :( \nWaa Kimaaaaaani prisssss!',
#   'neg'),
#  ('Baggage claim. The final goodbye to all your new plane friends :(', 'neg'),
#  ('i miss niamh i havent seen her in forever :(', 'neg'),
#  ('Yeah I screwed up again :-( and this time I thought I did something good good',
#   'neg'),
#  ('@lifeboatsupport I have! :(', 'neg'),
#  ("@CherylWalmsley hmmm, they always have so much sugar in them, I rarely make them. Sorry I couldn't help. :(",
#   'neg'),
#  ('I literally have no time to watch paper towns :((', 'neg'),
#  ("@donhutch4 what's the score don I'm stuck at work :(", 'neg'),
#  ('Agh @UPCIreland keeps cutting out in the middle of #undercoverboss :-(',
#   'neg'),
#  ('@CMPunk @MattJackson13  please please come back to wwe :( تكفى', 'neg'),
#  ("@cosplayamerica I'll be there around 10. My train was delayed. :(", 'neg'),
#  ('Having a full time job means you only gonna have part time fun :(', 'neg'),
#  ('My cats have forgotten who I am and they hate me :(', 'neg'),
#  ("@vaxwell I know it's long and I played for 15 hours. :(", 'neg'),
#  ('@NewBreed_Next u already have most of them :(', 'neg'),
#  ('@Kryaotic117 @TritanArmyv2 @MoreConsole yep again :(', 'neg'),
#  ('WHY MUST THE VIDEO STOP THO :(', 'neg'),
#  ('wisdom teeth giving me so much ache :((', 'neg'),
#  ('Y is no one up :-(', 'neg'),
#  ('my wrists feel so naked bc i forgot my watch &amp; bracelet :((', 'neg'),
#  ('@diamaziing Did you ligo na? :(', 'neg'),
#  ('The Day A Dozen Parents And Children Killed A Baby Shark For A Selfie :(  https://t.co/S8cq6c91ni',
#   'neg'),
#  ('So this is Heartache? :(', 'neg'),
#  ("I don't think so :( #zayniscomingback", 'neg'),
#  ("little mix are coming to sweden tomorrow and i can't see them :-( im sad",
#   'neg'),
#  ("my heart is breathing for this moment in time, i'll find the words to say before you leave me today :(",
#   'neg'),
#  ("Elmhurst FC are over  :-( I'll always be  #ETID", 'neg'),
#  ("Miss chillin'with you :( @PrincessReeev", 'neg'),
#  ("Forget to my Job. \nI'm sorry my father. :(", 'neg'),
#  ('@Scruffbucket IsTanya going2supply all d EXTRA infrastructure,teachers,doctors,nurses,paramedics&amp;other countless things2cope with it all?&gt;:(',
#   'neg'),
#  ('I liked a @YouTube video http://t.co/93Z6WOVOs9 PASHA IS CRYING AFTER TERRIBLE DONATE :(',
#   'neg'),
#  ("i'm so bored!!! pleas can 1 Arianator talk to me? :(", 'neg'),
#  ('@Hydrojeon lmao hahahaha slr jgh from school :((', 'neg'),
#  ('My live streaming sucks or is it just me :(', 'neg'),
#  ("Kendall and Kylie are killing me on Kylie's snapchat :(((((", 'neg'),
#  ('@MaayanGean absolute world to me I was so close to seeing him but he did not show up in manila :( i cried so fucking hard that time',
#   'neg'),
#  ('@jmcefalas Jeebus. Reabsorbtion of tooth, abscess, threatening to affect my lovely front crown :( and OOOOOOOOUCH!!!',
#   'neg'),
#  ('oh barney :((', 'neg'),
#  ('Awh why :( were nice  https://t.co/5zAwc5Z37J', 'neg'),
#  ("Sometimes it be's like that, yo. Follow someone and then a few days later realise they're problematic as fuck. Life :(",
#   'neg'),
#  ('THEY DIDNT EXPECT THAT OMG THEIR FACES :((((( IM SO PROUD OF YOU INFINITE',
#   'neg'),
#  ('This day is such a mess! :(', 'neg'),
#  ("I miss you maa :( why didn't you ever tell me its going to be like this without you?",
#   'neg'),
#  ('Help me :(', 'neg'),
#  ('@TheHinduTheatre @evam_entd Why no Bangalore? :(', 'neg'),
#  ('@NotRedbutBlue awww :(\nat least u never got called luis manzano tho',
#   'neg'),
#  ('@bebeshaaa thanks shaaaa! Miss u super :(', 'neg'),
#  ("WE DIDN'T GET THE 7TH WIN :(", 'neg'),
#  ('Meeting with the convener at 2:30pm :( not looking forward to it!', 'neg'),
#  ("@tweetseamus how was the party last night? Shame I couldn't go :( would of been lovely to have seen you again x",
#   'neg'),
#  ('@SynergyFlying No!!! Why did you delete me?:(', 'neg'),
#  ('#TURKEY ARE NOW #BOMBING #ISIS IN #SYRIA,AND ALLOW THE #USA TO USE ONE OF IT #AIRFIELDS FOR THEIR #JETS :()',
#   'neg'),
#  ("I want Jack's follow so bad, but I don't want to be annoying by spamming him :( sooo @jackgilinsky follow me please? ☺💜",
#   'neg'),
#  ("mommy's in manila and I've only seen her once :(", 'neg'),
#  ("The reason why I'm always, always overweight... sigeg habhab :( masud pa kaha kos akong un… http://t.co/RZ52EUtzMD http://t.co/Nvx057PFZp",
#   'neg'),
#  ("@samayanyan yes thank u!! Oh damn that hella sucks :-( but at least u had a really good time that's all that matters",
#   'neg'),
#  ('@mollehgarcia no pala omg hahaha i have driving lessons :(', 'neg'),
#  ('aW i wanna go and see dolphins again :( so cute xxx http://t.co/RJBAFfSMbh',
#   'neg'),
#  ('@brighteyedmgc hoLY FUCK are u okay / text me if u need anythin !!! :-(',
#   'neg'),
#  ('@xband__loverx I miss you :(', 'neg'),
#  ('#ZaynIsComingBackOnJuly26\nI See this trend an in radio the next sing is See you again...:(',
#   'neg'),
#  ('Beware: agonising thought experiment ahead :( https://t.co/B8Ttz1wbkG',
#   'neg'),
#  ('Last time I was here, was a funeral and a again funeral. Modimo ho tseba wena fela. :( — feeling emotional at... http://t.co/mQYsswdot7',
#   'neg'),
#  ("what's wrong with me :(", 'neg'),
#  ('@lh_JM88 and now me too :( hubby will be delighted to return home lol',
#   'neg'),
#  ("SO SAD FOR THE GIRLS OH WHY DIDN'T THEY WIN :((((", 'neg'),
#  ('@burloutray4 I want something new too, damn you bills!! :(', 'neg'),
#  ('@someboysjumper @apriloumay Nowt worse than a sad looking willy :(', 'neg'),
#  ('@Tonynamly sad moment when you gon vomit all this out :(', 'neg'),
#  ('or a famous bowl :(', 'neg'),
#  ("She's so cute :( http://t.co/5gRpttMX8k", 'neg'),
#  ('Devastating to find out last night that Titan AE was never actually any good :-( http://t.co/zzwd8HDcOI',
#   'neg'),
#  ('@Mark23Baracael mark followback :(', 'neg'),
#  ("@Latoyasilmon omg...you're so beautiful... miss you soooooooo much...: (",
#   'neg'),
#  ('@itstishh miss you so much :( xxxxxx', 'neg'),
#  ("i used to have such nice hair :(( look at it it's all shiny and long and wavy im emo http://t.co/qX7XO8x5Zq",
#   'neg'),
#  ("@LittleMix have fun in Germany :( I can't be there 😭", 'neg'),
#  ('I was about to make tea but load shedding was like Ha.a bheyps not now ! Ayemso Hacked :(((( http://t.co/ZudfTknvCM',
#   'neg'),
#  ('my left ear is swelling :(', 'neg'),
#  ('read sm quotes on fb which remind me abt sm 1 and am missing him so much now :(',
#   'neg'),
#  ('everyone is going to womad but me :(', 'neg'),
#  ("wut the hell i can't sleep &gt;:(", 'neg'),
#  ("@CorCor84 It is a vicious circle isn't it :(  x", 'neg'),
#  ('@eydiespi there is no surprise :(', 'neg'),
#  ('Win tickets to Cody Simpson concert in Singapore on August 10! http://t.co/6t9XKgtwTm #SpinorBinMusicXCodySimpson pls pls :(',
#   'neg'),
#  ('@joyce_gleek Sorry poooo. :(', 'neg'),
#  ('Sorry na bh3s :( @alrakakire', 'neg'),
#  ("Project I want to enter into #PitchWars may not work. :( Only first chap? Mine's a phone call transcript. #ugh",
#   'neg'),
#  ("@5SOSTumblrx the APMA's :(", 'neg'),
#  ("this is bad. my shoulder has started to hurt like a bitch :( and we're just a day away from competition! hope it'll be fine in time",
#   'neg'),
#  ("@shuaijerks it's okay I feel you it happens all the timw :(", 'neg'),
#  ("@HeyyLawley don't make the other accs feel bad :( that's just rude", 'neg'),
#  ('@meowkenzi :(( that sucks. Try vitamin e oil massage everyday for a while and it should make them healthier and easier to stretch',
#   'neg'),
#  ("What the hell is going wrong :( I don't understand why people choose to hurt each other https://t.co/hIBjz4fC2r",
#   'neg'),
#  ("I don't know what I'm doing for #BlockJam at all since my schedule's just whacked right now :(",
#   'neg'),
#  ('@tymoss wish I could have been there :(', 'neg'),
#  ('GUYS add my KIK - thelock76 #kik #kiksexting #sex #omegle #couple #travel #hotgirls :( http://t.co/Dn6agZcPhd',
#   'neg'),
#  ('Valentine et al (2009) found relationships between homo/biphobic comments &amp; certain disciplines- incl. European languages, lit, education :(',
#   'neg'),
#  ('3 ghantay say light nai hay :(', 'neg'),
#  ("@hereisjoshhiles I have it still won't work :(", 'neg'),
#  ('Rejection is the reason why people deny what they really feel.\n:( @maryjan71973628',
#   'neg'),
#  ('this weather is ruining everything :(', 'neg'),
#  ('@krysseners No, I was in Laguna :((((', 'neg'),
#  ('Feeling sick :(', 'neg'),
#  (':( exit gomen', 'neg'),
#  ("@sustinsantos what the heck that's not fair 😂 I grew half an inch in two years :(",
#   'neg'),
#  ('Woke up feeling so sick :(', 'neg'),
#  ('I wish you cut your hair like this again :( http://t.co/Oyt8wMo7w9', 'neg'),
#  ("@NerfThorn problem is 1. I'm from UK so it's £ not $ and 2. I don't have $25 :(",
#   'neg'),
#  ('Suuuuuuuper sick :( fever got way worse :(', 'neg'),
#  ('Me right Now :( http://t.co/hoVZi9wQnx', 'neg'),
#  ('65% digital sales.. having a bad feeling :(', 'neg'),
#  ('can I use anyones netflix my account is inactive and I wanna watch orphan black :(((',
#   'neg'),
#  ('havent seen you earlier :(', 'neg'),
#  ('@FairyFunFwee whaaat? what is this :((', 'neg'),
#  ("@margauxxemm yes baby kaya i'm so sorry :(((((", 'neg'),
#  ('NAAAAAN PAS GOODBYE STAGE :(', 'neg'),
#  ("@AppleMusic why does my music keep pausing randomly? It's the only app open :(",
#   'neg'),
#  ('3:30am walk down Inglewood ummm bad idea :( ugh stupid anxiety', 'neg'),
#  ("And it's not easy to be me :(", 'neg'),
#  ('@LittleMix Belgium :(', 'neg'),
#  ('@randomdavemcc1 This one was ready in 3 weeks and is also Charcoal, but the other one wont be ready til mid-end Aug :-(',
#   'neg'),
#  ("NOOoo @PTTBath  I've just heard the news :(", 'neg'),
#  ('@Rodnerbroo rip rodFanta :-(', 'neg'),
#  ('I wish I was better with words :-(', 'neg'),
#  ('@Wapaseeto yes, all wasp stings have been averted. Those bugs are mean  :(',
#   'neg'),
#  ('Can u feel it? :((:( #exo http://t.co/ghsa262ORm', 'neg'),
#  ("@zoellaftmendes please don't leave :(", 'neg'),
#  ("I'm feel so seekly...:(", 'neg'),
#  ('Shocking News!!! :( #RIPTito', 'neg'),
#  ("@Charalanahzard I can't see it! I'm sorry. Call me a manbearpig, but I cannot see it. Sorry :(",
#   'neg'),
#  ('Can i grow shorter pls :(', 'neg'),
#  ('@NimrodYEle Academics :-(((((', 'neg'),
#  ('I want my free @UberUK ice cream! :-( http://t.co/2BHfR9BU26', 'neg'),
#  ('"Exclusive to Germany" how unfair is that? :( Esp. regarding the current bleak german charts situation, still no entry even @ top 100. Pfft.',
#   'neg'),
#  ('@kwangqiiii later I feel out of place :((', 'neg'),
#  ('@borapls it was white washed dude to the Polaroid effect :-(', 'neg'),
#  ('I feel bad for talking to you... :(', 'neg'),
#  ("#newbethvideo i love you sooo much! But... I live in Greece so I dont think I'm gonna win :( But always hope!!!! &lt;3",
#   'neg'),
#  ('@courtneypink07 Haha I know right :( He needs a good talking to that Xur does!',
#   'neg'),
#  ('@GorobaoElisha Imy too :(', 'neg'),
#  ("@Emmalaalaaa I don't even know what's going on :( fill me in please? !\n\n#soon babe... ♡♥♡♥\n\nXoxoxo",
#   'neg'),
#  ("@for1rose it's raining here :( but I will make sure I get a picture of him soon",
#   'neg'),
#  ("|| I want cereal.\n\nToo bad we doN'T HAVE ANY. &gt;:(", 'neg'),
#  ('just got home. lost one of my stud earrings :(', 'neg'),
#  ('I miss his massages :(', 'neg'),
#  ('KIK me guys : hunde6 #kik #kikhorny #tagsforlikes #skype #kikchat #amazon #kikhorny :( http://t.co/jGB5W5ct7t',
#   'neg'),
#  ('i lost my 3.4k :(', 'neg'),
#  ('Yach.. telat.. huvvft..., :( https://t.co/nrzfh7Roja', 'neg'),
#  ("@junhuiass IT'S BEEN YEARS SINCE I HAVE BEEN IN A ZOO AND IT'S ONLY ON FIELDTRIPS SO NO TIME TO TOUCH :(((",
#   'neg'),
#  ('@attepate I wanted to hug him after watching this :(', 'neg'),
#  ('@JackAndJackReal I missed the following spree :( next time though x',
#   'neg'),
#  ('Still hoping :( #ZaynIsComingBackOnJuly26', 'neg'),
#  ('@EdeLabayog awww :(( kaya yan! Think positive!', 'neg'),
#  ('i miss my king,future,boss, and RAIN :( http://t.co/RZTM0VKIlM', 'neg'),
#  ("I want to watch a movie, listen to Sizwe, eat and write my assignments at the same time.... But I can't do that :(",
#   'neg'),
#  ('@strawberrybon i miss you :(', 'neg'),
#  ("this time in 20 days i'll have my results kms :(", 'neg'),
#  ('I have four shifts left with @taylorchurchman my heart has broken :(',
#   'neg'),
#  ('AAAAAHHHHHHHH  :(  It Is Only 3 pm And I Feel Like Dying Of Boredom....',
#   'neg'),
#  ('@HouseOfPoitiers @nurseneddy @Peteski40 \n\nOn me birthday en all :(',
#   'neg'),
#  ('Stop playing with my feelings man :( i aint got no time for that. *still hoping* ♡\n #ZaynIsComingBackOnJuly26 http://t.co/Nu0PMyGKU9',
#   'neg'),
#  ('@zedxgarcia u started it :(', 'neg'),
#  ('Am I the one whos dont see sinse to trend something like thats? :( #ZaynIsComingBackOnJuly26',
#   'neg'),
#  ("Good thing I got those free earrings, as I've somehow lost one of the tiny screw on ball things from one of my barbells :(",
#   'neg'),
#  ("@JonnyMalee owww I'm only about this weekend, I'm on the course next week so won't be able to get into Amsterdam :(",
#   'neg'),
#  ("@rainymondays luv u 💖 ps. We haven't talked in a looooong time :-( why??",
#   'neg'),
#  ('@gclliva home? but my eyes aint apartement : (', 'neg'),
#  ('@JackJcnes text: :( why', 'neg'),
#  ('@enikotsz @pooj_ @UberUK @walls With this rain though? :(', 'neg'),
#  ('@ollgbroxei sc, longe :(', 'neg'),
#  ("@AmeAmeSakura especially when you don't like it :( I can't do the same song over and over again :/",
#   'neg'),
#  ('Cat on the lap. I have to go out now! :( http://t.co/wN3169K7Kb', 'neg'),
#  ("@ellierowexo :((( &amp; I'm litro gonna be on my own that weekend", 'neg'),
#  ('@GiannePeqs shit good shepherd is lami :( 3', 'neg'),
#  ('@hawkerclaw thank you. Maybe because of late sleep. :(', 'neg'),
#  ('I need relax.:-( ...#lungomare #Pesaro #giachietittiwedding #igersoftheday #summertime #summer… https://t.co/IHFceHoxl3',
#   'neg'),
#  ('my nose is bruised a lil :( :(', 'neg'),
#  ('Fuck those snake things in Journey. Always went for me, never my partner. Had a beautiful scarf and he ate it :(',
#   'neg'),
#  ("@jaredlovesjen i'm hoping that if he comes back to aus i can afford to go again but i dont think i'll be able to :(",
#   'neg'),
#  ('It just ruins your #FridayFeeling when you know next day you have to wake up early in the morning....:(',
#   'neg'),
#  ("I'll be so sad if there's nothing tonight :(", 'neg'),
#  ('I want a bad bitch but I aint got no money :(', 'neg'),
#  ("but i can't fry chicken, woe is me my nigga :(", 'neg'),
#  ('#MOTN though lighting is not doing my make-up any justice :( http://t.co/nkzA8S687N',
#   'neg'),
#  ("That one person. Is still very important to me...and I don't want her gone any longer...yet I just sit here scared out of my mind. :(...",
#   'neg'),
#  ('i rly wanna buy the limited ver as well as the normal edition. huhuhu what to choose? :(',
#   'neg'),
#  ("@axolotl74 @sp1305 Stack is on M'Lady J8 to J11 M20 :-(", 'neg'),
#  ('jk im so bored :(( acads scheduled @ 8 what to do nowwww', 'neg'),
#  ("@HAMEZR10 couldn't watch cops :( how was James?", 'neg'),
#  ('i need to clean my window at some point today bc hugh keeps pawing at them and leaving muddy marks everywhere :(',
#   'neg'),
#  ("But I don't know what song to sing :(", 'neg'),
#  ('@xcliffordpizza my mom called me up :(((( i got distracted', 'neg'),
#  ('@YseIcedTey heyy i miss you :(', 'neg'),
#  ("Please be nice tomorrow weather! Otherwise our picnic is cancelled and I've got 24 cupcakes to eat :-( https://t.co/LGQRwfFTiO",
#   'neg'),
#  ('@Benzyyyyy with you talaga the best. :-( 😂', 'neg'),
#  ('the only female i wanna get it poppin with is Joc.... but she be playin :(',
#   'neg'),
#  ('@taekookfever SO CUTE :(', 'neg'),
#  ('@NinaSarto pm me :(', 'neg'),
#  ('When I saw #ZaynIsComingBackOnJuly26 "FIX YOU" by Coldplay plays in my Windows Media Player :( 😭 http://t.co/rGnNYzc31c',
#   'neg'),
#  ('@_ferdelicious I think I just failed one subj :-( sobrang bv 😭 pls pray for me huhu',
#   'neg'),
#  ('zamn the line up for afropunk fest brooklyn :(', 'neg'),
#  ("@lightmytorch I'm not there anymore!! Would have signed if I saw you! :( thank you for coming",
#   'neg'),
#  ('wish id put more than £50 on real madrid #shithouse :(', 'neg'),
#  ('Cutest dance ever :((', 'neg'),
#  ('@Kimwoobin89__ oppa............./hug ur arm/ why am I like this :(', 'neg'),
#  ('@jasonbarnard86 @stefgingerball I asked my boss for a raise once, he handed me a ladder and told me to climb the ladder to success. :-(',
#   'neg'),
#  ('@jenandmish @wittykrushnic to get by, to get by :(', 'neg'),
#  ('Nerve wracking test. Booset. :(', 'neg'),
#  ("@mythor aw sad :( it's very very long though. Maybe a little longer &amp; you'd love it? I restarted assassins creed II heaps, then fell in love",
#   'neg'),
#  ("@cragdoo I don't know why the hell it's playing the next one, I can find no way of turning that off :(",
#   'neg'),
#  ('Bored :(', 'neg'),
#  ("i'm such a terrible daughter :-(", 'neg'),
#  ('Finally got some time to catch up on games..Wish i could say "Let the games begin"...sigh*..PS3 isn\'t working :( http://t.co/nwriRgSq8v',
#   'neg'),
#  ('my ankle :(', 'neg'),
#  ("I just stepped in a puddle :-( &amp; I'm wearing slippers!!", 'neg'),
#  ('Good eve. :(', 'neg'),
#  ('wake up bby, imy :(', 'neg'),
#  ('I will cry :(', 'neg'),
#  ('Video: sararocs: I am so angry at the world :( http://t.co/eGuM20hTok',
#   'neg'),
#  ('pretty hairs :(', 'neg'),
#  ('fnaf 4 coming after my holiday now :(', 'neg'),
#  ('@1q4h_ cheer up!! :-( 😘💖', 'neg'),
#  ('@ThisIsTheBrooks maybe a tweet? :(', 'neg'),
#  ("@AnnieAppelle and @nutriculum is this today but you're not here :(  #anywayhedidanicejob",
#   'neg'),
#  ('@bethisbest01 @styleswavy same same 😞 :(', 'neg'),
#  ('this match history :(', 'neg'),
#  ("It's 3am and I can't sleep :(", 'neg'),
#  ('@JagexAlfred the green one is ugly :( the others are awesome tho', 'neg'),
#  ('Local legend :( https://t.co/VVLTlmOsQ0', 'neg'),
#  ("@CruiseLineUK @AzamaraVoyages can't tell you how sad I am we booked on another cruise line and could have done this. Double wail. :-(",
#   'neg'),
#  ('When things go wrong they go wrong I have broken my manual wheelchair checked if I can get one that fits from NHS and its 26weeks wait :(',
#   'neg'),
#  ("Poor SBENU :&lt; SaSin wasn't happy at all... As the best player on his team.. :(\nBut Anarchy~~~ :3 &lt;3",
#   'neg'),
#  ('@jenxmish rude af, im gonna put my candle away :(', 'neg'),
#  ('@wydbaylee im sure anyone would kiss ur forehead &amp; give u medicine if u asked :( but ur welcome :(',
#   'neg'),
#  ('@Marsaliath Oops :(', 'neg'),
#  ('Hoya mah always good looking :(\nNo comment aing :(', 'neg'),
#  ('@JKottak without you just miss you :(', 'neg'),
#  ('Nobody said it was easy :(', 'neg'),
#  ("I'm so sorry I didn't give you enough hugs awhile ago b I was just so tired :( But it was so nice seeing you again luv @nicoooootine",
#   'neg'),
#  ('@Jaxonoys aw I miss you :(', 'neg'),
#  ('@GoodieNuff now hush gurly and bring your purty mouth closer\n\nThat made me shiver :(',
#   'neg'),
#  ("@MojangSupport the website doesn't have the solution, is there anything I can do, I paid for this and I can't even play it properly :(",
#   'neg'),
#  ('Dont know why I try anymore. Getting tired of this. :(', 'neg'),
#  ('@RyanSugandi gol pea :(', 'neg'),
#  ('@SPObabbby I hate myself for not knowing English :(', 'neg'),
#  ('Physically, emotionally, mentally, #TIERD :(', 'neg'),
#  ("My third eye's getting active again :(", 'neg'),
#  ('@EggNiGreg thnkyouuuuuuuuu :(', 'neg'),
#  ("@simonshieldcars Hi Caroline no we didn't :( Neither did @MotorMistress or @GlynHopkinShop I think - we figured out it was in US lol",
#   'neg'),
#  ('@hotsootaff my mirror is more beautiful than me :(', 'neg'),
#  ("@nuttyxander didn't make it to the highlights then :-(  They seem to have stopped talking about 'climbing on pure courage' - bit too fishy",
#   'neg'),
#  ("I didn't even do anything to it idek :(", 'neg'),
#  ('did I missed apink performance? :(', 'neg'),
#  ('Bulet gendut :(', 'neg'),
#  ('#PARTY goodbye stage :(', 'neg'),
#  ('@subharrie noo :( do you know why?', 'neg'),
#  ('@lollypng :( *hugs* I hope you can rest soon.', 'neg'),
# ...
#  ('@iainbruce not good :(', 'neg'),
#  ('My original ticket was £19 :(', 'neg'),
#  ("@Jakers787 depends on when I have a vet visit for sick cat :( I'll let you know?",
#   'neg'),
#  ("@jenxmish @wittykrushnic don't leave :(", 'neg'),
#  ("i don't wanna get up :(((", 'neg'),
#  ("@elyusia i can find most major people EXCEPT his VA\n\ni'm not sure if they just kept it same as luminous but they didn't do that in kms &gt;:(",
#   'neg'),
#  ('@countrychoiceID min follback :(', 'neg'),
#  ('@martinamegia_ its been treating me horribly ugh :( im v happy for u !',
#   'neg'),
#  ("@kristikay13 Good morning! Hope it's a productive one for you. Time for me to get ready for work. :(",
#   'neg'),
#  ('"zayn" starts with a small letter Z. Why? :( @Real_Liam_Payne', 'neg'),
#  ("@lifelesscurves they're really unique and refreshing :( the popularity was great too. Just why...just why &gt;_&gt;",
#   'neg'),
#  ('Once you start loving someone, it’s hard to stop.\n*Bebeeeee :(', 'neg'),
#  ('CHEM LT WAS NOT NICE :(((', 'neg'),
#  ('.@sabal_abla @tanha_messiah Because people who point out inaccuracies in jokes might be inaccurate jokes. I got worried :(',
#   'neg'),
#  ('@DarkSkinnedToni burning rn like this is so tragic :(((', 'neg'),
#  ('I woke up really hungry :(', 'neg'),
#  ('I love Joy :(', 'neg'),
#  ('INFINITE GOT TO WIN &gt;:(', 'neg'),
#  ('@PlanetRockRadio Sam I have seen rush 19 times. Would have been 20 in Toronto until my flight was cancelled on day of the show :( stuart',
#   'neg'),
#  ("Party's goodbye stage :((", 'neg'),
#  ("Iyalaya to anybody that would laugh at me today. I'd just have to wear my shades round the clock.:(",
#   'neg'),
#  ('What is this ??? #ZaynIsComingBackOnJuly26 :( ;(', 'neg'),
#  ('@godstalia aw fuck that sucks :((', 'neg'),
#  ("@sianyw As if he wouldn't be happier here running around my house wearing a H&amp;M shirt. :(",
#   'neg'),
#  ('@Mars_Sum41 noooo :( goodbye fun driving', 'neg'),
#  ("I'm bored :( this one ubusy le fifa -_-", 'neg'),
#  ('@lorrainepalileo @cailaaah i wanna go gymnastics with you guys :(( haha',
#   'neg'),
#  ("I'm so sick aahhhh i hate this feeling :-(", 'neg'),
#  ('Ok, back to work :( http://t.co/QFtLZ2Cl0w', 'neg'),
#  ('My poor noggin! Bumped it a few days ago and it still hurts a little. :( #feelslikeanidiot',
#   'neg'),
#  ("I'm forever eating like  Pregnant woman these Days :-(", 'neg'),
#  ('Ugh :( My head hurts.', 'neg'),
#  ('i dearly miss and love my sunshine @zaynmalik :-(', 'neg'),
#  ('@PatelPatelxx @Starbucks can suk ma buttttttt. except their pumpkin scones.... but they havent made those in years :(((',
#   'neg'),
#  ('love outnumbered so much, wish there were more to watch :(', 'neg'),
#  ('vidcon :(((', 'neg'),
#  ('@ErisLovesMovies :( Feel better soon, Eris. #support', 'neg'),
#  ('Hello ;3 geez.. i badly miss my 12 precious stars :( EXO&lt;3', 'neg'),
#  ('@Beyfan1981 @HateTheseFools Yes Hive always sucks at voting... that is shit :((',
#   'neg'),
#  ("They said #GOT7 will back to #VIETNAM this december !!!!! I DUNT THINK SO AWWWWWWWW :(( DON'T KID ME !!!!",
#   'neg'),
#  ('@marmaisxcz IKR :( lol', 'neg'),
#  ('can you hear my sobbing :((( http://t.co/Daoz0uAQGC', 'neg'),
#  ('so cute :( http://t.co/hhhWQQ1Nh3', 'neg'),
#  ("@sociopathslut @onikashabibi but why don't I have buff legs yet :(", 'neg'),
#  ('noo toni deactivated too?? :(', 'neg'),
#  ("Bra Shady's kisses though!  :-( #Isibaya", 'neg'),
#  ('this place will forever hold a very special place in my heart :-( ❤️ gonna miss you Germany 😓 http://t.co/fwDwYoVEPV',
#   'neg'),
#  ("Haven't really slept all night :( I'm in a different place where it's a little colder. Hopefully that will help. Took some meds",
#   'neg'),
#  ("Leaving for the airport soon :( don't wanna go home.", 'neg'),
#  ('@clemencycox i want a sausage roll :-(', 'neg'),
#  ('Rain rain go away :(', 'neg'),
#  ('work adios friends :(', 'neg'),
#  ('I have a cold sore :( ew h8 this. Help', 'neg'),
#  ("What's wrong with my fb messenger :((((", 'neg'),
#  ('I wish my band were shittier so we could get booked on Leno :(', 'neg'),
#  ('Identity crisis :(', 'neg'),
#  ('3:33 am and all of my roommates are officially knocked out :( so much for an all nighter',
#   'neg'),
#  ("A bird just flew into the window and now it's dead :-(", 'neg'),
#  ('@damnkathleen come thru b I miss you :(', 'neg'),
#  ('@XxJenniferAmyxX Derek likes to tour &amp; visits Wetherspoons Pubs across the UK. Get Police to contact their H/O. Hope he OK. :(',
#   'neg'),
#  ('@LittleMix PLEASE FOLLOW ME :(', 'neg'),
#  ('Even had a dream that Frank Ocean released his new album ffs pls :((((',
#   'neg'),
#  ('Snapchat me : LisaHerring19 #snapchat #kikme #kikmeboys #woman #ebony #weloveyounamjoon #sexi :( http://t.co/zVTYSy29uk',
#   'neg'),
#  ("Don't know why I gave my white dress with small polka dots away :( 😭😭 *sigh* ndi hacked.",
#   'neg'),
#  ('I miss my baby :-(', 'neg'),
#  ("@HerFaithness it is &amp; I'm already having a bad day :-(", 'neg'),
#  ('@erinaree It was SO yum but I had to feed 6 so no leftovers :(', 'neg'),
#  ("@dullandwicked @_GrahamPatrick @JohnBoyStyle Has nobody told you about this side of twitter? It's in the T&amp;Cs. He owns you now. Sorry. :(",
#   'neg'),
#  ('The last dick pic I got was awful. It ruined walnut whips for me for life :-( \n\nI also named him and it turned out his wife followed me.',
#   'neg'),
#  ('@Vicionius Boah! :(', 'neg'),
#  ("Things are hard right now, &amp; I can't even be home with Mady to help me through it. :(",
#   'neg'),
#  ('i am so :((((((', 'neg'),
#  ('@EpicRaver I know :(', 'neg'),
#  ("@NatalieH__xx aww no but it's my last semester ever!! :( we def have to catch up sometime soon. We always leave it too long",
#   'neg'),
#  ('This manga is just too cute and yet made me cry.. :( http://t.co/KB6GswBxMT',
#   'neg'),
#  ('@LouiseMensch Just like that here at the moment....not. :-(', 'neg'),
#  ("I ate all the leftovers of the giant #AmINormalYet cookie for breakfast and now I'm clutching my poorly tummy in my PJs and groaning :(",
#   'neg'),
#  ('@ghinesaddi miss you :(', 'neg'),
#  ('@_stroya nou youre not :-( here have a picture of Adam http://t.co/WEvVpVoAmx',
#   'neg'),
#  ('@sinSALEM this is a very sad moment :(', 'neg'),
#  ("@lukelegs69\rthat wouldn't be right :((", 'neg'),
#  ('Ken Saras. Waiting for my sister. She was in accident. So poor :( https://t.co/44TvKaVDCJ',
#   'neg'),
#  ('@Rorington95 did they manage to sort your ticket issue mate? Nobody picked up when i rang the box office :(',
#   'neg'),
#  ('Fk!!!!! I have no freaking words to describe this.... Eric Prydz How? like how? :( This is out of the world!! http://t.co/W5uDTzdhAi',
#   'neg'),
#  ("Not 12 hours after my sister-in-law installed that new @DionoUSA seat we bought her she was rear-ended! everyone's fine but seat is trash :(",
#   'neg'),
#  ("For the first time in my life I've had to hold my boobs whilst running down stairs, is my no bra life over :(",
#   'neg'),
#  ('@ljenkins314 @fringenerd @Noin007 I like paper books :(', 'neg'),
#  ('@SensodyneIndia we friends love to eat ice cream during childhood. Missing those days :( #Toothsensitivity',
#   'neg'),
#  ('@father me too :-(', 'neg'),
#  ('@Belinda_Factor stressful :( you not even my dress size ke shem..', 'neg'),
#  ('Trust me to be no well :( Awell not be long and I will be to drunk to care #weekendofmadness 🍹🍸🍹',
#   'neg'),
#  ('i really like this cb but not the outfit this time too bad :(', 'neg'),
#  ('@lucyreesxo She threatened me :(', 'neg'),
#  ('i wanna be a dancer \nno\ni wanna be a choregrapher\nbut \nI CANT :(\nwhyyyyyyyyyyyy is life so unfair',
#   'neg'),
#  ('@KittyKatPK happening anymore :(', 'neg'),
#  ("@curiouskittten didn't even know you still existed on here haha text me :( 626-430-8715",
#   'neg'),
#  ("@subharrie @roguefond i've messaged her but she hasn't replied and i dont even think she's active on facebook :(",
#   'neg'),
#  ("@MlREU but i'm at work you hoe xD i can't even look at bby in peace :(((",
#   'neg'),
#  ('@suziepanol WHY DO THAT TO US :(', 'neg'),
#  ('Well it seems like just a dream :(', 'neg'),
#  ("Dream team recording today :((( im sad xiu couldn't make it :(", 'neg'),
#  ('Nk gi uss on birthday :(', 'neg'),
#  ("@HollieB awwwwww, I'm so sorry to hear that :(", 'neg'),
#  ('@ElisseJoson miss you so much ate elisse :(( do u still remember me? 😭',
#   'neg'),
#  ('i miss them so much :(', 'neg'),
#  ('ksoo makes me so emo :((((((((((((((((((((((((((((((((', 'neg'),
#  ('Wat a small session tat was :(..but still im little happy bcoz for the first time i heard my name from @rithvik_RD..but still too short..',
#   'neg'),
#  ("@Doomcrew_Glen awwwww i'm so sorry. :( i bet she's looking down on you&lt;33",
#   'neg'),
#  ("no matter how many times i try to sleep... i can't :(", 'neg'),
#  ('“@shakyra_cledera: "paper town" :--((((” sm :(((', 'neg'),
#  ("@wittykrushnic don't go :(", 'neg'),
#  ("I'm going to miss you baby! :(( @ Rancho Imperial de Silang Subdivision https://t.co/b5JvTqpm4N",
#   'neg'),
#  ('traffic :-(', 'neg'),
#  ('Twitter Help Center | Why can&amp;#39;t I follow people? https://t.co/LeL2yOp3Iq via @support i really really sorry about following evry one :(',
#   'neg'),
#  ('@franksredhotuk Its not hot in Cornwall! its veritably cold :( great prize xx',
#   'neg'),
#  ('@hancoverdalexo aww :( thanks anyway!!', 'neg'),
#  ('Regular gym workouts are so boring when you could be spinning :(', 'neg'),
#  ("I can't do it anymore. I can't have stress on my body yet my life is based upon stress I just can't do it :(",
#   'neg'),
#  ("@ManOfZinc And I don't see a penny of it... :-( DM me your email address; I'll send you the ebook.",
#   'neg'),
#  ('Фотосет: addicted-to-analsex: sweetbj: #sweetbj #blowjob Mhhh, want to make a man happy now :( http://t.co/v9ryND7pcs',
#   'neg'),
#  ('im sed.. :-( the person im meeting is late and im at the other end of sg and i havent taken my dinner yet bless me',
#   'neg'),
#  ('@willing_h I feel left out :(', 'neg'),
#  ('@mblaq_seungh0 THEN WHY MENTION MEE OMG /envious/ please oppa eonni stop lovey dovey in front of your poor single dongsaeng :(',
#   'neg'),
#  ("@ShannonEastwood I'm workin :( got a day off Tuesday tho haha x", 'neg'),
#  ('@ulaaaaa1909 Schade :(', 'neg'),
#  ('@CuddlesAri I am gutted! they NEVER do m&amp;g for Belfast :(', 'neg'),
#  ('@klentmagsino im so jealous.. :( because you followed each other with Jacob @JacobWhitesides .. follow me too. Jacob :(',
#   'neg'),
#  ('isco :(', 'neg'),
#  ('@ImRefleex my penis is too small :(', 'neg'),
#  ('omg me every fucking month... :( https://t.co/FX0CGVPDMX', 'neg'),
#  ('I wish my dog liked to cuddle :(', 'neg'),
#  ('Come on Carlton :(', 'neg'),
#  ('@MOONEMOJAI babe :( can u still read thru the conversation on ur hushed?',
#   'neg'),
#  ("Sometimes I wonder what went wrong :( guess I'll never know", 'neg'),
#  ('And more violence... :(  ...we are a Soul Sick nation...praying for Louisiana.\n#Lafayette #matteroftheheart #peace',
#   'neg'),
#  ('waduh..pantes :( https://t.co/AWS63BItZA', 'neg'),
#  ('@keelzy81 you know, I actually got suspended for smoking, can you believe it? Teenage me was such a fucking cliche :(',
#   'neg'),
#  ('Already miss @mikeyyfontt so much :(', 'neg'),
#  ('@BocasSweets I miss youuuu :((((', 'neg'),
#  ('Today #RMA jersey :(', 'neg'),
#  ('@ButDinero your so fake I texted you :(', 'neg'),
#  ('@Earl_Wolf24 not you :(', 'neg'),
#  ("♥ [ENG] ♥ - Let's talk, since can't stream games :(: http://t.co/bkNxSZfjm6",
#   'neg'),
#  ('@RuneMagique chance :(', 'neg'),
#  ('Snapchat me - JaclinTiler #snapchat #snapchat #teens #models #likeforlike #mpoints #hotfmnoaidilforariana :( http://t.co/xxuygooKcq',
#   'neg'),
#  ('@superslothjai hi, can you do me some dms with luke please??:(', 'neg'),
#  ('@AmandaT_Photo @OandtheFoxes really wanted to but ran out of time :(',
#   'neg'),
#  ('i hate waking up in the middle of my sleep :(', 'neg'),
#  ('he he he :(', 'neg'),
#  ("@rupexo @LordOfTheMics fuckkk it's a Wednesday :(", 'neg'),
#  ('@PetiteMistress DO IT! I want to start one for making small games, but I feel like I need to get a jump start before asking for support :(',
#   'neg'),
#  ('Justin where are you ? :( @justinbieber', 'neg'),
#  (":( :( I'm gonna cry", 'neg'),
#  ("@IanHallard @ArtsTheatreLDN I'm really excited but also really sad because once again I won't be able to see it :(",
#   'neg'),
#  ("I can't finish my Sanum today! :(\n#LLAOLLAO #Dessert but too full", 'neg'),
#  ('@jxstkatie @TheSvante i want foood :((', 'neg'),
#  ('Last day :(', 'neg'),
#  ('#UberIceCream was super! But we didnt get the glares :( @Uber_Pune', 'neg'),
#  ("@ffyeahh i don't know how to do vines :(", 'neg'),
#  ("@selenagomez you was Tweetin earlier this morning &amp; i wasn't here :( sad mood all the day :(",
#   'neg'),
#  ('sunggyu has a plaster on his elbow.... is it from the fall? :-(', 'neg'),
#  ('@ughimnotsam i am in the middle of figuring out how to choreo :(( next time girl!!',
#   'neg'),
#  ('@Afooo93 😭 this is me thinking she was well offensive, how can you laughing :(',
#   'neg'),
#  ("@NEEDTOBREATHE love you..sad I wasn't up front :(", 'neg'),
#  ('YEYY finally but my HD brows kit is broken slightly :(( @cohorted http://t.co/5CNhhfJpnJ',
#   'neg'),
#  ('@alexandraloisee Monday until wednesday, g na girl!!!! :(', 'neg'),
#  ('Babe :(', 'neg'),
#  ('I miss everyone omg :( school sux :(', 'neg'),
#  ('@gelcababa enjoy :(', 'neg'),
#  ('Add my KIK : nothaveld765 #kik #hornykik #edm #sexy #likeforfollow #hannibal #camsex :( http://t.co/EHtsuDdRuA',
#   'neg'),
#  ('new mosquitoe bites :(', 'neg'),
#  ('@CRMDKS are you into kinky shit--- we hsould justget married already : (',
#   'neg'),
#  ('really dont wanna go home today :(', 'neg'),
#  ('@Idamelatim you la :(((', 'neg'),
#  ('when nothing like us comes up on shuffle :((', 'neg'),
#  ('@notch hmm. I have been thinking about getting one for a while. Might get one inte future. I really miss buckling springs :(',
#   'neg'),
#  ('Ah Millz askies :( "@_Millzxy3D: so you come back and awusasho ? :\'( @Nessa_Mbeki"',
#   'neg'),
#  ('@sainsburys guys a really unlucky one. The driver and I briefly checked eggs but my other half spotted this : ( http://t.co/WpCqJHhBVk',
#   'neg'),
#  ('Tired :(', 'neg'),
#  ('im greatful that i can still see u despite of 144p :(', 'neg'),
#  ("@pikaiba I LOVE BROOKE I'm just concerned cause his face is all cracked :(",
#   'neg'),
#  ('＠maverickgamer_\u3000July 24, 2015 at 07:32PM \u3000:(', 'neg'),
#  ('＠maverickgamer_\u3000July 24, 2015 at 07:25PM \u3000:(', 'neg'),
#  ('Bored to the max rn :(', 'neg'),
#  ('@tudipa Sorry that manage files on external SD card via AirDroid is not supported now (Android 4.4+) :( Google has restricted that.',
#   'neg'),
#  ('@fkluca u are so cute thank u :(', 'neg'),
#  ("@MICHAELC24H it's alright... cramps are killing me. :-(", 'neg'),
#  ("MAYBE IT'S WRONG TO SAY PLEASE LOVE ME TOO &lt;/3 :(", 'neg'),
#  ('@blockedmefat dont unstan tay :( never please', 'neg'),
#  ("@Sibulela_M only white things I have ngeze turn up :( for all white parties I've been to. Have nothing cocktaily and classy 😭😭😭 so stressed.",
#   'neg'),
#  ('@wbuharryy i love you :(', 'neg'),
#  ('＠maverickgamer_\u3000July 24, 2015 at 07:24PM \u3000:(', 'neg'),
#  ("I don't want to be stuck inside all day :((", 'neg'),
#  ('@cmonlukey all of them :(', 'neg'),
#  ('@BeardOfTsu @LucasWeatherby @ChrisJLatimer @Alex_AMS96 it came crashing down and it hurts inside :(',
#   'neg'),
#  ("✈️2 days and I'm back in rainy UK :-(☔️", 'neg'),
#  ("@peterpalmer52 Hi Peter, We've not had pens for 2 years now. We just can't get them. There's not even spares in the office anymore either :(",
#   'neg'),
#  ('@Biblioticaa I got delayed by guests. Sigh :(', 'neg'),
#  ("@riseagainst why you don't come to Barcelona this year? :( won't be able to see you in Madrid or Bilbao...",
#   'neg'),
#  ('I hate Japanese call him "bani" :( :(', 'neg'),
#  ('wish I had a nice booty :-((((', 'neg'),
#  ("Who was next?? Oh yeah Sharyl! Currently don't got no #Shane ta call my own :( http://t.co/mOZlqwvvq0",
#   'neg'),
#  ('all of my favourite people deactivate :(', 'neg'),
#  ('I want to dance rn :(', 'neg'),
#  ('im still giddy over d1 :-(', 'neg'),
#  ('his smile is so beautiful :( https://t.co/OiAHorQJOb', 'neg'),
#  ('@heidsbland @asos95 yes, after 11 days. With a broken zipper.  Broken beyond repair. :(',
#   'neg'),
#  ...]

# %%
# clean text
def process_text(text):
    stemmer = PorterStemmer()
    stopwords_english = stopwords.words('english')
    #text = text.str
    text = str(text)
    text = re.sub(r'\$\w*', '', text)
    text = re.sub(r'^RT[\s]+', '', text)
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text)
    text = re.sub(r'#', '', text)
    tokenizer = TweetTokenizer(preserve_case=False, strip_handles=True,reduce_len=True)
    text_tokens = tokenizer.tokenize(text)

    text_clean = []
    for word in text_tokens:
        if (word not in stopwords_english and  
                word not in string.punctuation): 
            stem_word = stemmer.stem(word)  # stemming word
            text_clean.append(stem_word)
            
    sentence = ' '.join(text_clean)
    
    return sentence

# categorical label
def cat_label(label):
    if label == 'neg':
        value = -1
    elif label == 'pos':
        value = 1
    return value 

# split for x and y 
def xy(dataset):
    df = pd.DataFrame(dataset, columns = ['text', 'label'])
    df['text_clean'] = df['text'].apply(lambda r: process_text(r))
    #df['categorical_label'] = df.label.factorize()[0]
    df['categorical_label'] = df['label'].apply(lambda r: cat_label(r))

    x = df.text_clean
    y = df.categorical_label

    return x, y

# %%
# dataframe
x_train, y_train = xy(train_set)
x_test, y_test = xy(test_set)
x_valid, y_valid = xy(valid_set)

# %% [markdown]
# # Naive Bayes

# %%
model = Pipeline([
    ('bow',CountVectorizer()),  # strings to token integer counts
    ('tfidf', TfidfTransformer()),  # integer counts to weighted TF-IDF scores
    ('classifier', MultinomialNB()),  # train on TF-IDF vectors w/ Naive Bayes classifier
])

# %%
model.fit(x_train, y_train)
# Out:
# Pipeline(steps=[('bow', CountVectorizer()), ('tfidf', TfidfTransformer()),
#                 ('classifier', MultinomialNB())])

# %%
y_pred = model.predict(x_test)
print(confusion_matrix(y_pred,y_test))
print(classification_report(y_pred,y_test))
print(accuracy_score(y_pred,y_test))
# Out:
# [[593 235]
#  [157 515]]
#               precision    recall  f1-score   support
#
#           -1       0.79      0.72      0.75       828
#            1       0.69      0.77      0.72       672
#
#     accuracy                           0.74      1500
#    macro avg       0.74      0.74      0.74      1500
# weighted avg       0.74      0.74      0.74      1500
#
# 0.7386666666666667

# %% [markdown]
# # Apply into earnings call sentence

# %%
# import dataset
path = '/Users/timliu/Documents/GitHub/data_collecting/df_for_NLP/sentence_split_df.csv'
df_sentence = pd.read_csv(path)
df_sentence.head()
# Out:
#                                             sentence    participants    tense
# 0                                                 Hi  Andrew Ritchie  unknown
# 1                             Good morning, everyone  Andrew Ritchie  unknown
# 2  Could I just dig in a little bit more to the i...  Andrew Ritchie     past
# 3  Because you split that between man-made andNat...  Andrew Ritchie     past
# 4  I guess I'm justcurious that the budget is gro...  Andrew Ritchie     past

# %%
# drop participant columns as we dont need it
df_sentence = df_sentence.drop(['participants'], axis=1)

# %%
# check NaN values
print(df_sentence.isnull().sum())

# delete NaN rows
df_sentence = df_sentence.dropna()
# Out:
# sentence    0
# tense       0
# dtype: int64

# %%
# clean text for sentiment analysis
df_sentence['text_clean'] = df_sentence['sentence'].apply(lambda r: process_text(r))
df_sentence.head(5)
# Out:
#                                             sentence    tense  \
# 0                                                 Hi  unknown
# 1                             Good morning, everyone  unknown
# 2  Could I just dig in a little bit more to the i...     past
# 3  Because you split that between man-made andNat...     past
# 4  I guess I'm justcurious that the budget is gro...     past
#
#                                           text_clean
# 0                                                 hi
# 1                                  good morn everyon
# 2  could dig littl bit increas catbudget 2022 eur...
# 3  split man-mad andnatcat notic give split gave ...
# 4  guess i'm justcuri budget grow 18 proxi expect...

# %%
# making prediction
prediction = model.predict(df_sentence.text_clean)
prediction_label = np.array(['positive' if p==1 else 'negative' for p in prediction])
df_sentence['prediction_label'] = prediction_label
df_sentence['sentiment_score'] = prediction
df_sentence.head()
# Out:
#                                             sentence    tense  \
# 0                                                 Hi  unknown
# 1                             Good morning, everyone  unknown
# 2  Could I just dig in a little bit more to the i...     past
# 3  Because you split that between man-made andNat...     past
# 4  I guess I'm justcurious that the budget is gro...     past
#
#                                           text_clean prediction_label  \
# 0                                                 hi         positive
# 1                                  good morn everyon         positive
# 2  could dig littl bit increas catbudget 2022 eur...         positive
# 3  split man-mad andnatcat notic give split gave ...         negative
# 4  guess i'm justcuri budget grow 18 proxi expect...         positive
#
#    sentiment_score
# 0                1
# 1                1
# 2                1
# 3               -1
# 4                1

# %%
Counter(df_sentence['prediction_label'])
# Out:
# Counter({'positive': 184, 'negative': 100})

# %%
df_final = df_sentence[['sentence', 'prediction_label', 'sentiment_score']]
df_final.head(5)
# Out:
#                                             sentence prediction_label  \
# 0                                                 Hi         positive
# 1                             Good morning, everyone         positive
# 2  Could I just dig in a little bit more to the i...         positive
# 3  Because you split that between man-made andNat...         negative
# 4  I guess I'm justcurious that the budget is gro...         positive
#
#    sentiment_score
# 0                1
# 1                1
# 2                1
# 3               -1
# 4                1

# %%
def check(num):
    print(df_final.sentence[num])
    print(f'Prediction: {df_final.prediction_label[num]}')

# %%
check(3)
# Out:
# Because you split that between man-made andNatCat, because I noticed you give that split now, you gave us split for '21
# Prediction: negative

# %%
check(100)
# Out:
# So overall, that should round up the picture probably.Clemens Jungsthof elBut definitely the COVID -- the reported COVID claims, not necessarily booked claims,but as COVID -- or the identified COVID claims have reporting lag of four to six weeksand even then they are not necessarily reliable, because an awful lot of people,everybody who gets into a hospital, gets tested on COVID, and if it's positive, even if thathas nothing to do with the fact that, he just had a car accident and if he dies, he will bereported as a COVID claim in many countries
# Prediction: negative

# %%
check(50)
# Out:
# The bond recovery is very, very high
# Prediction: positive

# %%
check(120)
# Out:
# On burned, Vinit, you know that we have placed a little over EUR300 million of wholeaccounts coverage
# Prediction: positive

# %% [markdown]
# # To paragraph

# %%
# import dataset
path_pata = '/Users/timliu/Documents/GitHub/data_collecting/df_for_NLP/paragraph_split_df.csv'
df_para = pd.read_csv(path_pata)
df_para.head()
# Out:
#                                                 text          participants
# 0  Hi. Good morning, everyone. Could I just dig i...        Andrew Ritchie
# 1  Sure.Jean-Jacques Henchoz-- this year, so it's...        Andrew Ritchie
# 2  Great. Thanks very much. Thank you.Jean-Jacque...        Andrew Ritchie
# 3  Hey, good morning. Thank you very much. So, a ...        Vinit Malhotra
# 4  On the cash flow, nothing really significant. ...  Unidentified Speaker

# %%
df_join = df_final.copy()
df_join.head(5)
# Out:
#                                             sentence prediction_label  \
# 0                 Good morning, ladies and gentlemen         positive
# 1   I welcome you to today's Hannover Re Internat...         positive
# 2   For your information, this conference isbeing...         negative
# 3   At this time, I would like to hand the call o...         negative
# 4       JeanJacques Henchoz, Chief Executive Officer         negative
#
#    sentiment_score
# 0                1
# 1                1
# 2               -1
# 3               -1
# 4               -1

# %%
# split paragraphs into sentences
split_list = []
for para in df_para.text.values:
    sentences = para.split(sep = '.')
    split_list.append(sentences)

# %%
# find which paragraph that sentences fall fot.
def find_para(line):
    no = 'No found'
    for i, value in enumerate(split_list):
        if line in value:
            no = i
            break
    return no

# %%
df_join['no_para'] = df_join['sentence'].apply(lambda r: find_para(r))
df_join.head(5)
# Out:
#                                             sentence prediction_label  \
# 0                 Good morning, ladies and gentlemen         positive
# 1   I welcome you to today's Hannover Re Internat...         positive
# 2   For your information, this conference isbeing...         negative
# 3   At this time, I would like to hand the call o...         negative
# 4       JeanJacques Henchoz, Chief Executive Officer         negative
#
#    sentiment_score no_para
# 0                1       0
# 1                1       0
# 2               -1       0
# 3               -1       0
# 4               -1       0

# %%
df_join[10:15]
# Out:
#                                              sentence prediction_label  \
# 10  The next question is from Vinit Malhotra, Medi...         positive
# 11                              Your line is now open         positive
# 12                                     Please goahead         negative
# 13  The next question is from William Hardcastle, UBS         positive
# 14                              Your line is now open         positive
#
#     sentiment_score no_para
# 10                1      14
# 11                1      14
# 12               -1      14
# 13                1      21
# 14                1      14

# %% [markdown]
# Problem 1: 14 sentences not in any paragraphs.

# %%
df_no_found = df_join.loc[df_join['no_para']=='No found']
print(len(df_no_found))
df_no_found
# Out:
# 14
#                                               sentence prediction_label  \
# 31   Ladies and gentlemen, thank you for your atten...         positive
# 32                        This call has been concluded         positive
# 33                                   Youmay disconnect         negative
# 207                     Questions And AnswersThank you         positive
# 210   Andrew, if I may add, you shouldn't see that ...         positive
# 245  On P&C growth, Sven, do you want to add?Vinit,...         positive
# 256   And then, could you just repeat yourquestion ...         positive
# 476   COVID 3Q, that looked a bit lower and thatcou...         positive
# 509   Is that because of the greater fronting on Eu...         negative
# 512   Is there anything why that'shappened? Is ther...         positive
# 516   Is that a very fair assumption?And just on th...         negative
# 517           Is that how weshould read that?Brilliant         positive
# 559                                    But again --Yes         positive
# 584   Why should we not be thinking that these are ...         positive
#
#      sentiment_score   no_para
# 31                 1  No found
# 32                 1  No found
# 33                -1  No found
# 207                1  No found
# 210                1  No found
# 245                1  No found
# 256                1  No found
# 476                1  No found
# 509               -1  No found
# 512                1  No found
# 516               -1  No found
# 517                1  No found
# 559                1  No found
# 584                1  No found

# %% [markdown]
# Problem 2: Some sentences appears a lot of paragraphs.

# %%
for line in df_para.text.values:
    #x = re.findall('Your line is now open',line)
    x = re.findall('Your line is now open',line)
    if len(x) >0 :
        print(line)
    else:
        print('Nope')
# Out:
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# The next question is from Vinit Malhotra, Mediobanca. Your line is now open. Please goahead.
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# The next question is from William Hardcastle, UBS. Your line is now open. Please goahead.
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# The next question is from Thomas Fossard, HSBC. Your line is now open. Please goahead.
# Nope
# Nope
# Nope
# Nope
# The next question is from Iain Pearce, Credit Suisse. Your line is now open. Please goahead.
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# The next question is from Darius Satkauskas of KBW. Your line is now open. Please goahead.
# Nope
# Nope
# And we have a follow-up question from Vinit Malhotra, Mediobanca. Your line is now openagain.
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
# Nope
